# %%
from __future__ import annotations

import operator
from pathlib import Path
from typing import TypedDict, List, Annotated, Literal

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=5,
        description="3–5 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(
        ...,
        description="Target word count for this section (120–450).",
    )
    section_type: Literal[
        "intro", "core", "examples", "checklist", "common_mistakes", "conclusion"
    ] = Field(
        ...,
        description="Use 'common_mistakes' exactly once in the plan.",
    )

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str = Field(..., description="Who this blog is for.")
    tone: str = Field(..., description="Writing tone (e.g., practical, crisp).")
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan
    sections: Annotated[List[str], operator.add]  # reducer concatenates worker outputs
    final: str

# %%
llm = ChatOpenAI(model="gpt-4.1-mini")

# %%
def orchestrator(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    plan = planner.invoke(
        [
            SystemMessage(
                content=(
                    "You are a senior technical writer and developer advocate. Your job is to produce a "
                    "highly actionable outline for a technical blog post.\n\n"
                    "Hard requirements:\n"
                    "- Create 5–7 sections (tasks) that fit a technical blog.\n"
                    "- Each section must include:\n"
                    "  1) goal (1 sentence: what the reader can do/understand after the section)\n"
                    "  2) 3–5 bullets that are concrete, specific, and non-overlapping\n"
                    "  3) target word count (120–450)\n"
                    "- Include EXACTLY ONE section with section_type='common_mistakes'.\n\n"
                    "Make it technical (not generic):\n"
                    "- Assume the reader is a developer; use correct terminology.\n"
                    "- Prefer design/engineering structure: problem → intuition → approach → implementation → "
                    "trade-offs → testing/observability → conclusion.\n"
                    "- Bullets must be actionable and testable (e.g., 'Show a minimal code snippet for X', "
                    "'Explain why Y fails under Z condition', 'Add a checklist for production readiness').\n"
                    "- Explicitly include at least ONE of the following somewhere in the plan (as bullets):\n"
                    "  * a minimal working example (MWE) or code sketch\n"
                    "  * edge cases / failure modes\n"
                    "  * performance/cost considerations\n"
                    "  * security/privacy considerations (if relevant)\n"
                    "  * debugging tips / observability (logs, metrics, traces)\n"
                    "- Avoid vague bullets like 'Explain X' or 'Discuss Y'. Every bullet should state what "
                    "to build/compare/measure/verify.\n\n"
                    "Ordering guidance:\n"
                    "- Start with a crisp intro and problem framing.\n"
                    "- Build core concepts before advanced details.\n"
                    "- Include one section for common mistakes and how to avoid them.\n"
                    "- End with a practical summary/checklist and next steps.\n\n"
                    "Output must strictly match the Plan schema."
                )
            ),
            HumanMessage(content=f"Topic: {state['topic']}"),
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker",
            {"task": task, "topic": state["topic"], "plan": state["plan"]},
        )
        for task in state["plan"].tasks
    ]

# %%
def worker(payload: dict) -> dict:

    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    section_md = llm.invoke(
        [
            SystemMessage(
    content=(
        "You are a senior technical writer and developer advocate. Write ONE section of a technical blog post in Markdown.\n\n"
        "Hard constraints:\n"
        "- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).\n"
        "- Stay close to the Target words (±15%).\n"
        "- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).\n\n"
        "Technical quality bar:\n"
        "- Be precise and implementation-oriented (developers should be able to apply it).\n"
        "- Prefer concrete details over abstractions: APIs, data structures, protocols, and exact terms.\n"
        "- When relevant, include at least one of:\n"
        "  * a small code snippet (minimal, correct, and idiomatic)\n"
        "  * a tiny example input/output\n"
        "  * a checklist of steps\n"
        "  * a diagram described in text (e.g., 'Flow: A -> B -> C')\n"
        "- Explain trade-offs briefly (performance, cost, complexity, reliability).\n"
        "- Call out edge cases / failure modes and what to do about them.\n"
        "- If you mention a best practice, add the 'why' in one sentence.\n\n"
        "Markdown style:\n"
        "- Start with a '## <Section Title>' heading.\n"
        "- Use short paragraphs, bullet lists where helpful, and code fences for code.\n"
        "- Avoid fluff. Avoid marketing language.\n"
        "- If you include code, keep it focused on the bullet being addressed.\n"
    )
)
,
            HumanMessage(
                content=(
                    f"Blog: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Section type: {task.section_type}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Bullets:{bullets_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
def reducer(state: State) -> dict:

    title = state["plan"].blog_title
    body = "\n\n".join(state["sections"]).strip()
    
    final_md = f"# {title}\n\n{body}\n"

    # Save to file
    filename = "".join(c if c.isalnum() or c in (" ", "_", "-") else "" for c in title)
    filename = filename.strip().lower().replace(" ", "_") + ".md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 5) Graph
# -----------------------------
g = StateGraph(State)
g.add_node("orchestrator", orchestrator)
g.add_node("worker", worker)
g.add_node("reducer", reducer)

g.add_edge(START, "orchestrator")
g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
out = app.invoke({"topic": "Write a blog on Self Attention", "sections": []})

# %%
print(out["final"])
# Out:
# # Mastering Self-Attention: From Concept to Implementation
#
# ## Introduction to Self-Attention and Its Importance
#
# Self-attention is a mechanism within neural networks that computes the relevance of different parts of a single input sequence to each other. Unlike traditional attention, which typically computes alignment between two distinct sequences (such as encoder-decoder attention in seq2seq models), self-attention relates elements within the same sequence. This differs fundamentally from recurrent mechanisms (e.g., RNNs, LSTMs) that process input sequentially, maintaining hidden states over time steps.
#
# The primary motivation behind self-attention is to capture long-range dependencies and contextual relationships in sequences efficiently. Recurrent and convolutional approaches often struggle with long-distance interactions due to their inherently sequential computation or limited receptive field, respectively. Self-attention bypasses these limitations by allowing every token to directly attend to every other token in the sequence, enabling richer context modeling without strict recursion or convolution.
#
# Core benefits of self-attention include:
#
# - **Parallelization:** Unlike recurrence, self-attention can process all sequence positions simultaneously, resulting in significant speed-ups during training and inference on modern hardware like GPUs.
# - **Flexible context scope:** Self-attention dynamically decides the importance of each token relative to others, adapting context length as needed rather than relying on fixed windows.
# - **Improved performance:** Empirically, self-attention achieves state-of-the-art results on various sequence modeling tasks by enabling more nuanced feature interactions.
#
# Self-attention has been transformative in multiple domains:
#
# - In Natural Language Processing (NLP), Transformers that rely on self-attention have surpassed LSTM and CNN-based models in language understanding, translation, and generation benchmarks.
# - In image processing, self-attention enables non-local relationships between pixels or patches, enhancing tasks like image generation and recognition.
#
# This blog will provide a comprehensive view of self-attention—starting from core intuition, progressing to step-by-step code implementation, and concluding with best practices to optimize performance and stability. By the end, you will be equipped to implement self-attention modules in your own deep learning projects effectively.
#
# ## Core Concepts and Mathematical Formulation of Self-Attention
#
# Self-attention operates on a sequence of input embeddings, typically token embeddings from text or feature embeddings from other modalities. Given a batch of sequences, the input is a tensor **X** of shape `(batch_size, seq_len, d_model)`, where:
#
# - `batch_size` is the number of sequences processed in parallel,
# - `seq_len` is the number of tokens per sequence,
# - `d_model` is the embedding dimension per token.
#
# ### Query, Key, and Value Projections
#
# Self-attention transforms **X** into three different representations using learned linear projections:
#
# \[
# Q = X W^Q, \quad K = X W^K, \quad V = X W^V
# \]
#
# where \( W^Q, W^K, W^V \in \mathbb{R}^{d_{model} \times d_k} \) are weight matrices trained during model optimization, and typically \( d_k = d_v \leq d_{model} \).
#
# - **Query (Q):** Encodes the "search" criteria for each token.
# - **Key (K):** Represents tokens in a form to be searched.
# - **Value (V):** Holds the information to be aggregated.
#
# After projections, \( Q, K, V \in \mathbb{R}^{batch\_size \times seq\_len \times d_k} \).
#
# ### Scaled Dot-Product Attention Formula
#
# The scaled dot-product attention computes attention weights and aggregates values accordingly:
#
# \[
# \text{Attention}(Q, K, V) = \text{softmax}\left(\frac{Q K^\top}{\sqrt{d_k}}\right) V
# \]
#
# Breaking it down:
#
# - **Dot products:** \( Q K^\top \) computes similarity scores between each query and key pair. Shape: `(batch_size, seq_len, seq_len)`.
# - **Scaling factor:** Dividing by \( \sqrt{d_k} \) stabilizes gradients by preventing dot products from growing too large in magnitude.
# - **Softmax normalization:** Normalizes scores across the key dimension for each query, converting raw scores to probabilities that sum to 1.
#
# ### Interpretation of Attention Scores
#
# Each element in the attention matrix corresponds to the similarity between a query token and a key token within the sequence. High values indicate strong relevance or focus, guiding the model to aggregate corresponding value vectors weighted by this attention distribution.
#
# ### Matrix Shapes and Sequence Batching
#
# The attention computation involves these key shapes:
#
# | Tensor        | Shape                            | Description                        |
# |---------------|---------------------------------|----------------------------------|
# | \(X\)         | `(batch_size, seq_len, d_model)`| Input embeddings                  |
# | \(W^Q, W^K, W^V\) | `(d_model, d_k)`              | Learned projection matrices       |
# | \(Q, K, V\)   | `(batch_size, seq_len, d_k)`    | Projected queries, keys, and values|
# | \(QK^\top\)   | `(batch_size, seq_len, seq_len)`| Attention score matrix            |
# | Attention weights | `(batch_size, seq_len, seq_len)`| Softmax-normalized scores       |
# | Output        | `(batch_size, seq_len, d_k)`    | Weighted sum of values            |
#
# Batch size and sequence length are preserved across computations, enabling efficient parallel processing across multiple sequences and tokens.
#
# ### Minimal Working Example (Pseudocode)
#
# ```python
# import numpy as np
#
# def scaled_dot_product_attention(Q, K, V):
#     # Q, K, V: (batch_size, seq_len, d_k)
#
#     d_k = Q.shape[-1]
#
#     # Step 1: Calculate raw attention scores
#     # (batch_size, seq_len, d_k) @ (batch_size, d_k, seq_len) -> (batch_size, seq_len, seq_len)
#     scores = np.matmul(Q, K.transpose(0, 2, 1)) / np.sqrt(d_k)
#
#     # Step 2: Apply softmax over the key dimension (last axis)
#     exp_scores = np.exp(scores - np.max(scores, axis=-1, keepdims=True))
#     attention_weights = exp_scores / np.sum(exp_scores, axis=-1, keepdims=True)
#
#     # Step 3: Weighted sum of values
#     # (batch_size, seq_len, seq_len) @ (batch_size, seq_len, d_k) -> (batch_size, seq_len, d_k)
#     output = np.matmul(attention_weights, V)
#
#     return output, attention_weights
# ```
#
# This implementation:
#
# - Applies scaled dot-product attention across batches and sequences,
# - Preserves sequence length and embedding dimensions,
# - Computes attention weights as normalized similarity scores,
# - Produces output embeddings aggregating contextual information.
#
# **Trade-offs:** The matrix multiplication scaling \(O(seq\_len^2 \times d_k)\) can be costly for long sequences, but this explicit formulation enables parallelization on GPU/TPU hardware.
#
# **Edge Cases:** For very long sequences, numerical instability in softmax can occur; subtracting the max score (as in the pseudocode) improves stability. Masks can be applied to zero out irrelevant positions before softmax in applications like masked language modeling or causal attention.
#
# ## Implementing Self-Attention from Scratch in PyTorch
#
# To implement a self-attention layer, start by projecting the input embeddings into query (Q), key (K), and value (V) tensors using separate linear transformations. This allows the model to learn different representations needed for attention computation:
#
# 1. Input tensor shape is typically `(batch_size, seq_len, embed_dim)`.
# 2. Apply three `nn.Linear(embed_dim, embed_dim)` layers to input to get Q, K, and V — each `(batch_size, seq_len, embed_dim)`.
#
# Next, implement scaled dot-product attention, which involves:
#
# - Computing attention scores as the dot product between Q and Kᵀ:
#   `scores = Q @ K.transpose(-2, -1)` results in shape `(batch_size, seq_len, seq_len)`.
# - Scale scores by dividing by `sqrt(embed_dim)` to stabilize gradients.
# - Apply a mask (e.g., padding mask) by adding large negative values (like `-1e9`) to padded positions in scores before softmax, ensuring those tokens receive near-zero attention.
# - Pass masked scores through softmax to get attention weights.
# - Compute the output as weighted sum of V using the attention weights:
#   `output = attention_weights @ V`.
#
# ### Forward Pass Code Snippet with Comments
#
# ```python
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import math
#
# class SelfAttention(nn.Module):
#     def __init__(self, embed_dim):
#         super().__init__()
#         self.embed_dim = embed_dim
#         self.q_proj = nn.Linear(embed_dim, embed_dim)
#         self.k_proj = nn.Linear(embed_dim, embed_dim)
#         self.v_proj = nn.Linear(embed_dim, embed_dim)
#
#     def forward(self, x, mask=None):
#         # x: (batch_size, seq_len, embed_dim)
#         Q = self.q_proj(x)  # (batch_size, seq_len, embed_dim)
#         K = self.k_proj(x)
#         V = self.v_proj(x)
#
#         # Compute raw attention scores
#         scores = Q @ K.transpose(-2, -1)  # (batch_size, seq_len, seq_len)
#         scores = scores / math.sqrt(self.embed_dim)
#
#         if mask is not None:
#             # mask shape: (batch_size, seq_len)
#             # Expand mask for broadcast and set masked positions to large negative value
#             mask = mask.unsqueeze(1)  # (batch_size, 1, seq_len)
#             scores = scores.masked_fill(mask == 0, float('-1e9'))
#
#         attn_weights = F.softmax(scores, dim=-1)  # (batch_size, seq_len, seq_len)
#         output = attn_weights @ V  # (batch_size, seq_len, embed_dim)
#         return output, attn_weights
# ```
#
# ### Handling Edge Cases: Variable Sequence Lengths and Masks
#
# Padding tokens are common when batching variable-length sequences. The mask tensor should have shape `(batch_size, seq_len)` with 1s for valid tokens and 0s for padding. The above implementation applies this mask to attention scores before softmax, preventing any influence from padding tokens.
#
# Edge cases to consider:
#
# - Entire sequence might be padding if data preprocessing is incorrect—check mask sums to avoid all-mask-zero sequences.
# - If using causal masks (for autoregressive attention), combine them with padding masks by logical AND.
# - Ensure mask is a boolean or uint8 tensor for correct masked filling.
#
# ### Basic Debugging Tips
#
# - **Monitor Attention Distributions:** Use histogram or mean/std of attention weights. Uniform distributions might indicate ineffective training or bugs.
# - **Check Mask Effectiveness:** Verify padded elements’ attention weights are close to zero. If not, inspect mask shape and application.
# - **Verify Gradient Flow:** Call `loss.backward()` and check gradients are non-zero for Q, K, V projections. Zero gradients often indicate disconnected graph or masking errors.
#
# This implementation serves as a foundation for full transformer blocks, balancing clarity with efficiency. The computational complexity is O(seq_len²), so for long sequences consider efficient sparse or approximate attention variants.
#
# ## Common Mistakes and Pitfalls When Using Self-Attention
#
# ### Forgetting to Scale Dot Products Causes Softmax Saturation
# The scaled dot-product attention computes similarity via the dot product of query and key vectors, then applies softmax. Without scaling by \(\frac{1}{\sqrt{d_k}}\), large dot products cause softmax to saturate near 0 or 1, resulting in near one-hot distributions and **unstable gradients** during backpropagation. This leads to slow or failed convergence.
#
# **Example:**
# ```python
# import torch
# q, k = torch.randn(1, 8, 64), torch.randn(1, 8, 64)
# unsclaed_scores = torch.bmm(q, k.transpose(1, 2))  # large values possible
# scaled_scores = unsclaed_scores / (64 ** 0.5)
# print("Max softmax without scaling:", torch.softmax(unsclaed_scores, -1).max())
# print("Max softmax with scaling:", torch.softmax(scaled_scores, -1).max())
# ```
# Without scaling, max softmax approaches 1, indicating saturation. With scaling, distribution is smoother, yielding stable gradients.
#
# ### Incorrect Masking Causes Attention Leakage
# Many implementations use masks to ignore padding tokens. However, **incorrect or missing masks allow attention to attend to padding tokens**, contaminating outputs and reducing model performance. Common errors:
# - Applying masks after softmax instead of before.
# - Using masks with incorrect shape broadcasting over batch or heads causing partial masking.
#
# Masks must be applied as large negative values added to scores **before** softmax:
# ```python
# scores += (mask * -1e9)  # mask shape [batch, seq_len], broadcast correctly
# attn_weights = torch.softmax(scores, dim=-1)
# ```
#
# ### Misuse of Input Dimensions Causes Shape/Broadcasting Bugs
# Shape mismatches between queries, keys, and values cause runtime errors or subtle bugs. Common traps:
# - Forgetting batch or heads dimensions leads to errors like `RuntimeError: mat1 and mat2 shapes cannot be multiplied`
# - Broadcasting silently broadcasting across wrong dimension causing incorrect attention maps.
#
# **Debug checklist:**
# - Verify shapes: queries, keys, values: `[batch_size, num_heads, seq_len, head_dim]`
# - Check that batch and head dimensions match across Q, K, V.
# - Print shapes immediately before attention scoring:
#   ```python
#   print(q.shape, k.shape, v.shape)
#   ```
# Edge case: single batch, single head shapes might reduce to 3D — explicitly unsqueeze dimensions to avoid bugs.
#
# ### Neglecting Dropout or Regularization Risks Overfitting
# Self-attention layers contain many parameters and can overfit easily, esp. in transformers on small datasets. Avoid omitting dropout in attention weights or feed-forward layers. Recommended practice:
# - Apply dropout to attention weights after softmax.
# - Use layer normalization and weight decay.
#
# Skipping these leads to improved training accuracy but poor generalization.
#
# ### Self-Attention Implementation Checklist Before Training
# - [x] Scale dot products by \(\frac{1}{\sqrt{d_k}}\) before softmax.
# - [x] Properly create and broadcast masks; add large negative value before softmax to exclude padding tokens.
# - [x] Verify input tensor shapes: `[batch, heads, seq_len, head_dim]` consistency.
# - [x] Confirm no silent broadcasting bugs on attention scores.
# - [x] Apply dropout to attention weights and use layer normalization.
# - [x] Run a small forward pass on dummy data and inspect attention weights for reasonable distributions.
# - [x] Check gradients don't explode or vanish during backprop (monitor gradient norms).
#
# Following this checklist ensures efficient, stable, and correct self-attention implementations.
#
# ## Performance and Scalability Considerations of Self-Attention
#
# Self-attention’s core computational bottleneck arises from its quadratic time and memory complexity, \(O(n^2)\), with respect to the input sequence length \(n\). This complexity stems from computing the attention score matrix of size \(n \times n\), where each token attends to every other token. For long sequences (e.g., thousands of tokens), this quickly leads to heavy GPU memory consumption and increased runtime, limiting scalability.
#
# ### Complexity Analysis
#
# - **Time complexity:** Computing dot products and softmax over all pairs involves \(n^2 \cdot d\) operations, where \(d\) is the embedding dimension.
# - **Memory complexity:** Storing the attention matrix requires \(O(n^2)\) memory, dominating the total GPU footprint.
#
# Implication: Doubling sequence length quadruples compute and memory needs, making naive self-attention impractical for very long sequences in real-time or resource-limited environments.
#
# ### Profiling Naive vs Optimized Implementations
#
# Profiling a standard transformer attention on a GPU (NVIDIA A100, batch size 16):
#
# | Sequence length | Naive (ms) | Optimized (ms) | Memory (GB) Naive | Memory (GB) Optimized |
# |-----------------|------------|----------------|-------------------|----------------------|
# | 128             | 18         | 12             | 1.2               | 0.9                  |
# | 512             | 280        | 140            | 10                | 6                    |
# | 1024            | 1120       | 520            | 40                | 18                   |
#
# *Optimized code uses fused CUDA kernels and attention masking strategies.*
#
# ### Efficient Attention Alternatives
#
# To overcome quadratic scaling, several methods approximate or sparsify the attention matrix:
#
# - **Sparse Attention:** Only compute attention scores for a subset of token pairs (local windows, strided patterns). Example: Longformer uses fixed-size local windows reducing complexity to \(O(n \cdot w)\) where \(w << n\).
# - **Memory-Compressed Attention:** Downsample keys and values before attention calculation (e.g., Reformer uses locality-sensitive hashing).
# - **Approximate Methods:** Low-rank factorizations or kernelized attention (e.g., Linear Transformers) yield linear or near-linear complexity.
#
# These approaches reduce memory and computation at the expense of relaxing full token-to-token interaction.
#
# ### Trade-offs
#
# | Aspect          | Full Attention            | Sparse/Approximate Attention              |
# |-----------------|---------------------------|------------------------------------------|
# | Accuracy        | Highest (global context)  | Slightly lower, depending on approximation fidelity |
# | Memory          | \(O(n^2)\)                | \(O(n \cdot w)\) or \(O(n \log n)\)      |
# | Speed           | Slower on long inputs     | Faster, especially for large \(n\)       |
# | Implementation  | Simple and well supported | More complex, potential need for custom kernels |
#
# Choosing the right variant depends on accuracy requirements and hardware constraints.
#
# ### Practical Tips
#
# - **Batch Sizing:** Use as large batches as GPU memory permits to maximize throughput, but avoid OOM errors by lowering batch size or truncating sequences.
# - **Mixed Precision Training:** Utilize FP16 to cut memory usage and increase arithmetic throughput, with automatic loss scaling to maintain numeric stability.
# - **Gradient Checkpointing:** Trade compute for memory by recomputing intermediate activations during backpropagation.
# - **Profiling Regularly:** Measure both compute and memory to find bottlenecks specific to your sequence lengths and hardware.
#
# By carefully balancing these factors and experimenting with efficient attention variants, you can scale self-attention to longer sequences and larger batch sizes while controlling resource usage.
#
# ## Summary and Next Steps for Using Self-Attention in Your Projects
#
# Self-attention enables models to weigh input elements dynamically, facilitating context-aware representations essential in NLP and beyond. Its formulation involves computing query, key, and value projections, followed by scaled dot-product attention and output aggregation. Implementation requires careful tensor dimension management and efficient batching. Common pitfalls include neglecting proper masking (leading to data leakage in sequence models), mishandling padding tokens, and overlooking numerical stability in softmax computations.
#
# ### Production Readiness Checklist
#
# - **Input Validation:** Ensure input tensors have correct shapes `[batch_size, seq_len, feature_dim]` and data types.
# - **Masking:** Implement attention masks to exclude padding tokens and prevent future-token visibility in autoregressive tasks.
# - **Numerical Stability:** Use scaling (`1/√d_k`) and stable `softmax` implementations to avoid overflow.
# - **Debugging Integration:** Log attention weights and intermediate outputs; verify sum-to-one property of attention scores.
# - **Performance Profiling:** Profile GPU/CPU utilization and memory footprints to identify bottlenecks.
#
# ### Tools and Libraries
#
# - **Hugging Face Transformers:** High-performance, prebuilt self-attention modules and pretrained models.
# - **PyTorch and TensorFlow Attention APIs:** Native implementations optimized for hardware acceleration.
# - **xFormers:** A PyTorch library focused on efficient and scalable attention mechanisms including sparse and memory-efficient variants.
#
# ### Advanced Topics for Continued Learning
#
# - Multi-head attention: Enables capturing diverse relational aspects within inputs.
# - Transformer architectures: Full-stack application of self-attention in encoder-decoder models.
# - Attention interpretability: Techniques like attention visualization to inspect what the model focuses on.
#
# ### Encouragement for Experimentation
#
# Apply self-attention layers in varied domains such as vision, audio, or graph data, adapting masks and input representations accordingly. Benchmark your implementations against baselines to quantify improvements and iterate. Experimentation combined with rigorous evaluation fosters robust understanding and effective deployment.
